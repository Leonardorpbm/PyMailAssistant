# %% [markdown]
# ### Setup

# %% [markdown]
# #### Create a Secrets Folder: client_secret.json, gmail_token.json
# #### more in this video: https://www.youtube.com/watch?v=NQ6s4JFhGcc&t=269s
#
# #### Create an .env file:
# #### GENAI_API,, GENAI_KEY, GMAIL_USER_EMAIL, GMAIL_CREDENTIALS_PATH = "secrets/client_secret.json", GMAIL_TOKEN_FILE = #### "secrets/gmail_token.json"

# %%
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.header import Header
from jinja2 import Template

def generateEmailLayout(answer, list_of_sources, info_client):
    print(info_client)
    html_string = " "
    if info_client['insurer'] == "Allianz":
        print("Changed to Allianz")
        html_string += f'''<!DOCTYPE html
    PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//PT" "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
<meta http-equiv="Content-Type" content="text/html charset=UTF-8" />
<html lang="en">

<head></head>
<body style="
      background-color: #f3f3f5;
      font-family: HelveticaNeue, Helvetica, Arial, sans-serif;
    ">
    <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%"
        style="max-width: 680px; width: 100%; margin: 0 auto; background-color: #ffffff">
        <tr style="width: 100%">
            <td>
                <table style="display: flex; background: #f3f3f5; padding: 20px 30px" align="center" border="0"
                    cellpadding="0" cellspacing="0" role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <img src="https://upload.wikimedia.org/wikipedia/commons/4/4b/Allianz.svg" height="18px"
                                    style="
                      display: block;
                      outline: none;
                      border: none;
                      text-decoration: none;
                      filter: invert(100%) sepia(0%) saturate(7500%) hue-rotate(235deg) brightness(117%) contrast(102%);" />
                            </td>
                        </tr>
                    </tbody>
                </table>
                <table width="100%" style="
                    border-radius: 5px 5px 0 0;
                    display: flex;
                    flex-direction: column;
                    background-color: #003781;
            " align="center" role="presentation" cellspacing="0" cellpadding="0" border="0">
                    <tbody style="width: 100%">
                        <tr style="width: 100%; position: relative">
                            <td style="padding: 20px 30px 15px; position: relative">
                                <h1 style="
                                    color: #fff;
                                    font-size: 18px;
                                    font-weight: bold;
                                    line-height: 27px;
                                    text-wrap: balance;
                    ">
                                    Thank you for contacting Allianz!
                                </h1>
                            </td>
                            <td>
                                <div style="
                                    display: block;
                                    margin: 0px 20px 0 40px;
                                    width: 60px;
                                    height: 60px;
                                                    ">
                                    
                                </div>
                            </td>
                        </tr>
                    </tbody>
                </table>
                <table style="padding: 30px 30px 40px 30px" align="center" border="0" cellpadding="0" cellspacing="0"
                    role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <table width="100%" align="center" role="presentation" cellspacing="0" cellpadding="0"
                                    border="0">
                                    <tbody style="width: 100%">
                                        <tr style="width: 100%">
                                            <h4>Dear *Customer Name*,</h4>
                                            <h4>
                                                Responding to your question about whether it is possible not to undergo the inspection.
                                            </h4>
                                            <p>
                                                You can do so, provided that: <br><br>
                                                During the first 30 days of your contract, you adhere to the waiting period.
                                                You can only report damages to the company 30 days after the insurance start
                                                date because during this period, if you do not undergo the inspection, the Own Damage
                                                guarantees (Collision, Crash, and Overturning; Fire, Lightning, and Explosion;
                                                Theft or Robbery; Acts of Vandalism and Natural Phenomena) and the coverages for
                                                Isolated Glass Breakage and Replacement Vehicle are not in effect.
                                                <br><br>
                                                Liability, Travel Assistance, and Legal Assistance coverages are in effect from the moment
                                                your insurance begins.
                                            </p>
                                            <br />
                                            <p>With best regards,
                                            </p>
                                            <b>Ali,
                                                <br> <small style="color: #484848">Allianz Virtual Assistant</small></b>
                                        </tr>
                                    </tbody>
                                </table>
                            </td>
                        </tr>
                    </tbody>
                </table>
                <hr style="
                        width: 100%;
                        border: none;
                        border-top: 1px solid #eaeaea;
                        border-color: #cccccc;
                        margin: 20px 0;
                      " />
                <table style="
                        max-width: 680px;
                        width: 100%;
                        margin: 32px auto 0 auto;
                        padding: 0 30px;
                      " align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <p style="
                                font-size: 12px;
                                line-height: 15px;
                                margin: 0;
                                margin-top: 16px;
                                color: #9199a1;
                              ">
                                Received this email from an automated response system, which facilitates communication and allows
                                for the quick resolution of issues that can be answered promptly.
                                </p>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="/">I am not satisfied with the automated response. I would like this email to be reviewed by a human agent.
                                    </a>
                                </div>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="https://www.allianz.com/en/privacy-statement.html">Privacy Policy</a>
                                </div>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="https://www.allianz.com/en/about-us/brand/partnerships/olympic-paralympic-movements/gangwon-2024-123/online-learning-register/terms-conditions.html">Terms and Conditions</a>
                                </div>
                                <hr style="
                                max-width: 600px;
                                margin: auto;
                                border: none;
                                border-top: 1px solid #eaeaea;
                                margin: 30px 0;
                                border-color: #d6d8db;
                              " />
                                <img src="" height="14" style="
                                margin-top: 14px;
                                display: block;
                                outline: none;
                                border: none;
                                text-decoration: none;
                                margin-bottom: 12px;
                              " />
                                <div></div>
                                <a target="_blank" style="
                                color: #9199a1;
                                text-decoration: underline;
                                display: block;
                                font-size: 12px;
                                margin-right: 10px;
                                margin-bottom: 0;
                                margin-top: 12px;
                              " href="https://www.allianz.com/en.html">Allianz is a brand of the Allianz Group.</a>
                                <p style="
                                font-size: 12px;
                                line-height: 15px;
                                margin: 4px 0;
                                color: #9199a1;
                              ">
                                    <strong>Allianz Deutschland AG</strong> Koeniginstrasse 28 80802 Munich Germany
                                </p>
                            </td>
                        </tr>
                    </tbody>
                </table>
            </td>
        </tr>
    </table>
    </td>
    </tr>
    </tbody>
    </table>
    </td>
    </tr>
    </table>

    <table style="max-width: 680px; width: 100%; margin: 32px auto 0 auto; padding: 0 30px" align="center" border="0"
        cellpadding="0" cellspacing="0" role="presentation" width="100%">
        <tbody>
            <tr>
                <td>
                    <p style="
                font-size: 12px;
                line-height: 15px;
                margin: 0;
                margin-top: 16px;
                color: #9199a1;
              ">
                       You received this email from an automatic response system, which makes it easier to
                        communication and allows us to resolve questions that we can respond to
                        faster way.
                    </p>
                    <br />
                    <br /><a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.allianz.com/en/privacy-statement.html">Privacy Statement</a><br /><a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.allianz.com/en/about-us/brand/partnerships/olympic-paralympic-movements/gangwon-2024-123/online-learning-register/terms-conditions.html">Terms and Conditions</a>
                    <hr style="
                max-width: 600px;
                margin: auto;
                border: none;
                border-top: 1px solid #eaeaea;
                margin: 30px 0;
                border-color: #d6d8db;
              " />

                    <img src="https://brandslogos.com/wp-content/uploads/images/allianz-logo-black-and-white.png" height="20" style="
                margin-top: 14px;
                display: block;
                outline: none;
                border: none;
                text-decoration: none;
                " />

                    <br />
                    <a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.allianz.com/en.html">Allianz 2023. All Rights Reserved.</a>
                    <p style="font-size: 12px; line-height: 15px; margin: 14px 0px; color: #9199a1">
                        <strong>Allianz Deutschland AG</strong> Koeniginstrasse 28 80802 Munich Germany
                    </p>
                </td>
            </tr>
        </tbody>
    </table>
</body>

</html>
        '''
   
    elif info_client['insurer'] == "Zurich":
        print("Changed to Zurich")
        html_string += f'''<!DOCTYPE html
    PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//PT" "http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
<meta http-equiv="Content-Type" content="text/html charset=UTF-8" />
<html lang="en">

<head></head>
<body style="
      background-color: #f3f3f5;
      font-family: HelveticaNeue, Helvetica, Arial, sans-serif;
    ">
    <table align="center" role="presentation" cellspacing="0" cellpadding="0" border="0" width="100%"
        style="max-width: 680px; width: 100%; margin: 0 auto; background-color: #ffffff">
        <tr style="width: 100%">
            <td>
                <table style="display: flex; background: #f3f3f5; padding: 20px 30px" align="center" border="0"
                    cellpadding="0" cellspacing="0" role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <img src="https://upload.wikimedia.org/wikipedia/commons/e/e3/Zurich_Insurance_Group_Logo_Horizontal.svg" height="18px"
                                    style="
                      display: block;
                      outline: none;
                      border: none;
                      text-decoration: none;
                      filter: invert(100%) sepia(0%) saturate(7500%) hue-rotate(235deg) brightness(117%) contrast(102%);" />
                            </td>
                        </tr>
                    </tbody>
                </table>
                <table width="100%" style="
                    border-radius: 5px 5px 0 0;
                    display: flex;
                    flex-direction: column;
                    background-color: #003781;
            " align="center" role="presentation" cellspacing="0" cellpadding="0" border="0">
                    <tbody style="width: 100%">
                        <tr style="width: 100%; position: relative">
                            <td style="padding: 20px 30px 15px; position: relative">
                                <h1 style="
                                    color: #fff;
                                    font-size: 18px;
                                    font-weight: bold;
                                    line-height: 27px;
                                    text-wrap: balance;
                    ">
                                    Thank you for contacting Zurich Insurance Group!
                                </h1>
                            </td>
                            <td>
                                <div style="
                                    display: block;
                                    margin: 0px 20px 0 40px;
                                    width: 60px;
                                    height: 60px;
                                                    ">
                                    
                                </div>
                            </td>
                        </tr>
                    </tbody>
                </table>
                <table style="padding: 30px 30px 40px 30px" align="center" border="0" cellpadding="0" cellspacing="0"
                    role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <table width="100%" align="center" role="presentation" cellspacing="0" cellpadding="0"
                                    border="0">
                                    <tbody style="width: 100%">
                                        <tr style="width: 100%">
                                            <h4>Dear *Customer Name*,</h4>
                                            <h4>
                                                Responding to your question about whether it is possible not to undergo the inspection.
                                            </h4>
                                            <p>
                                                You can do so, provided that: <br><br>
                                                During the first 30 days of your contract, you adhere to the waiting period.
                                                You can only report damages to the company 30 days after the insurance start
                                                date because during this period, if you do not undergo the inspection, the Own Damage
                                                guarantees (Collision, Crash, and Overturning; Fire, Lightning, and Explosion;
                                                Theft or Robbery; Acts of Vandalism and Natural Phenomena) and the coverages for
                                                Isolated Glass Breakage and Replacement Vehicle are not in effect.
                                                <br><br>
                                                Liability, Travel Assistance, and Legal Assistance coverages are in effect from the moment
                                                your insurance begins.
                                            </p>
                                            <br />
                                            <p>With best regards,
                                            </p>
                                            <b>Zuri,
                                                <br> <small style="color: #484848">Zurich Insurance Group Virtual Assistant</small></b>
                                        </tr>
                                    </tbody>
                                </table>
                            </td>
                        </tr>
                    </tbody>
                </table>
                <hr style="
                        width: 100%;
                        border: none;
                        border-top: 1px solid #eaeaea;
                        border-color: #cccccc;
                        margin: 20px 0;
                      " />
                <table style="
                        max-width: 680px;
                        width: 100%;
                        margin: 32px auto 0 auto;
                        padding: 0 30px;
                      " align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" width="100%">
                    <tbody>
                        <tr>
                            <td>
                                <p style="
                                font-size: 12px;
                                line-height: 15px;
                                margin: 0;
                                margin-top: 16px;
                                color: #9199a1;
                              ">
                                Received this email from an automated response system, which facilitates communication and allows
                                for the quick resolution of issues that can be answered promptly.
                                </p>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="/">I am not satisfied with the automated response. I would like this email to be reviewed by a human agent.
                                    </a>
                                </div>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="https://www.zurich.com/en/sustainability/customers/zurich-data-commitment/data-protection-and-privacy">Privacy Policy</a>
                                </div>
                                <div>
                                    <a target="_blank" style="
                                  color: #9199a1;
                                  text-decoration: underline;
                                  display: block;
                                  font-size: 12px;
                                  margin-right: 10px;
                                  margin-bottom: 0;
                                  margin-top: 8px;
                                " href="https://www.zurich.com/en/commercial-insurance/products/marine/swift/terms-of-use">Terms and Conditions</a>
                                </div>
                                <hr style="
                                max-width: 600px;
                                margin: auto;
                                border: none;
                                border-top: 1px solid #eaeaea;
                                margin: 30px 0;
                                border-color: #d6d8db;
                              " />
                                <img src="" height="14" style="
                                margin-top: 14px;
                                display: block;
                                outline: none;
                                border: none;
                                text-decoration: none;
                                margin-bottom: 12px;
                              " />
                                <div></div>
                                <a target="_blank" style="
                                color: #9199a1;
                                text-decoration: underline;
                                display: block;
                                font-size: 12px;
                                margin-right: 10px;
                                margin-bottom: 0;
                                margin-top: 12px;
                              " href="https://www.zurich.com/en">Zurich Insurance is a brand of the Zurich Insurance Group.</a>
                                <p style="
                                font-size: 12px;
                                line-height: 15px;
                                margin: 4px 0;
                                color: #9199a1;
                              ">
                                    <strong>Zurich Insurance Group Ltd</strong> Corporate Center
                                    Mythenquai 2
                                    8002 Zurich
                                    Switzerland
                                </p>
                            </td>
                        </tr>
                    </tbody>
                </table>
            </td>
        </tr>
    </table>
    </td>
    </tr>
    </tbody>
    </table>
    </td>
    </tr>
    </table>

    <table style="max-width: 680px; width: 100%; margin: 32px auto 0 auto; padding: 0 30px" align="center" border="0"
        cellpadding="0" cellspacing="0" role="presentation" width="100%">
        <tbody>
            <tr>
                <td>
                    <p style="
                font-size: 12px;
                line-height: 15px;
                margin: 0;
                margin-top: 16px;
                color: #9199a1;
              ">
                       You received this email from an automatic response system, which makes it easier to
                        communication and allows us to resolve questions that we can respond to
                        faster way.
                    </p>
                    <br />
                    <br /><a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.zurich.com/en/sustainability/customers/zurich-data-commitment/data-protection-and-privacy">Privacy Statement</a><br /><a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.zurich.com/en/commercial-insurance/products/marine/swift/terms-of-use">Terms and Conditions</a>
                    <hr style="
                max-width: 600px;
                margin: auto;
                border: none;
                border-top: 1px solid #eaeaea;
                margin: 30px 0;
                border-color: #d6d8db;
              " />

                    <img src="https://cdn.freebiesupply.com/logos/large/2x/zurich-insurance-logo-png-transparent.png" height="20" style="
                margin-top: 14px;
                display: block;
                outline: none;
                border: none;
                text-decoration: none;
                " />

                    <br />
                    <a target="_blank" style="
                color: #9199a1;
                text-decoration: underline;
                display: inline-block;
                font-size: 12px;
                margin-right: 10px;
                margin-bottom: 0;
                margin-top: 8px;
              " href="https://www.zurich.com/en">Zurich Insurance Group Ltd 2023. All Rights Reserved.</a>
                    <p style="font-size: 12px; line-height: 15px; margin: 14px 0px; color: #9199a1">
                        <strong>Zurich Insurance Group Ltd</strong> Corporate Center
                                    Mythenquai 2
                                    8002 Zurich
                                    Switzerland
                    </p>
                </td>
            </tr>
        </tbody>
    </table>
</body>

</html>
        '''
    else:
        html_string += ""
    return html_string

    result_response = "At the moment, we have life, health, and automobile insurance..."
    list_of_sources = ["https://www.allianz.com/en/investor_relations/shareholders/faq.html"]
    result_database = {"nome":"Leonardo", "email": "leonardorpbm2@gmail.com", "insurer":"Allianz"} 
    html_string = generateEmailLayout(result_response, list_of_sources, result_database)
    file = open("email.html","w",encoding="utf-8-sig")
    print(file)
    file.write(html_string)
    file.close()

# %%
import os
import base64
from dotenv import load_dotenv
from googleapiclient.discovery import build
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from google_auth_oauthlib.flow import InstalledAppFlow
from email.mime.text import MIMEText
from email import message_from_bytes
from email.utils import parsedate_to_datetime
import email.utils

# Step 5: Load Environment Variables
load_dotenv()
CREDENTIALS_FILE = os.getenv("GMAIL_CREDENTIALS_PATH")
USER_EMAIL = os.getenv("GMAIL_USER_EMAIL")
TOKEN_FILE = os.getenv("GMAIL_TOKEN_FILE")
SCOPES = ['https://mail.google.com/']


def get_credentials():
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        flow = InstalledAppFlow.from_client_secrets_file(CREDENTIALS_FILE, SCOPES)
        creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return creds

def get_unread_emails(service):
    results = service.users().messages().list(userId='me', q='is:unread').execute()
    messages = results.get('messages', [])
    if not messages:
        print("No unread emails found.")
        return []
    else:
        unread_emails = []
        for email in messages:
            email_details = service.users().messages().get(userId='me', id=email['id'], format='metadata').execute()
            unread_emails.append(email_details)
        return unread_emails

def extract_message_body(part):
    if 'data' in part['body']:
        return base64.urlsafe_b64decode(part['body']['data']).decode('utf-8')
    elif 'attachmentId' in part['body']:
        attachment_id = part['body']['attachmentId']
        attachment = service.users().messages().attachments().get(userId='me', messageId=message['id'], id=attachment_id).execute()
        return base64.urlsafe_b64decode(attachment['data']).decode('utf-8')
    elif 'parts' in part:
        return extract_message_body(part['parts'][0])
    return ""

def extract_message_date(headers):
    for header in headers:
        if header['name'] == 'Date':
            return parsedate_to_datetime(header['value'])
    return None

def get_message_history(service, message_id):
    # Get the message thread containing the given message_id
    thread = service.users().threads().get(userId='me', id=message_id, format='full').execute()

    # Extract and concatenate all messages in the thread
    messages = thread['messages']
    message_history = ""
    for message in messages:
        message_body = extract_message_body(message['payload'])
        print(message_body)
        message_date = extract_message_date(message['payload']['headers'])
        if message_date:
            formatted_date = message_date.strftime("%a, %d %b %Y %H:%M:%S %z")
        else:
            formatted_date = "Unknown Date"
        message_history += f"<br>From: {message['payload']['headers'][0]['value']}<br>Date:{formatted_date}<br><br>{message_body}"
        #print(message_body)
    return message_history


# This function is not being used
def reply(service, message_id, reply_text, subject_prefix="Re"):
    message = service.users().messages().get(userId='me', id=message_id, format='full').execute()
    headers = message['payload']['headers']

    # Extracting the original sender's email address from the headers
    sender = [header['value'] for header in headers if header['name'] == 'From'][0]

    # Extracting all original recipient's email addresses from the headers
    recipients = [header['value'] for header in headers if header['name'] == 'To' or header['name'] == 'Cc' or header['name'] == 'Bcc']

    # Extracting the subject of the original email
    subject = [header['value'] for header in headers if header['name'] == 'Subject'][0]

    reply_subject = f"{subject_prefix}: {subject}"

    # Get the message history to include in the reply
    message_history = get_message_history(service, message_id)

    # Create a plain text message
    reply_message = MIMEText(f"{reply_text}\n\n-----Original Message-----{message_history}")
    reply_message['From'] = ", ".join(recipients)
    reply_message['To'] = sender
    reply_message['Subject'] = reply_subject
    
    # Set the 'In-Reply-To' header to the original email's message-id
    reply_message['In-Reply-To'] = message['id']

    # Find the existing thread ID and include it in the reply
    thread_id = message['threadId']

    # Encode the message to base64
    raw_message = base64.urlsafe_b64encode(reply_message.as_bytes()).decode()

    reply = {
        'raw': raw_message,
        'threadId': thread_id  # Set the thread ID for the reply to be part of the existing thread
    }

    # Send the reply and get the response
    response = service.users().messages().send(userId='me', body=reply).execute()

    # Extract the threadId and Id of the new email from the response
    new_thread_id = response.get('threadId', None)
    sent_reply_message_id = response.get('id', None)

    # Prints para visualizar os ID's
    #print(f"Sender: {sender}")
    #print(f"Repliers (Recipients): {', '.join(recipients)}")
    #print(f"Subject: {subject}")
    #print(f"Original Message ID: {message_id}")
    #print(f"New Email Thread ID: {new_thread_id}")
    #print(f"Sent Reply Message ID: {sent_reply_message_id}")
    #print(f"Thread ID for Reply: {thread_id}")
    print(f"Replied to email from (Recipients): {', '.join(recipients)} as ")
    print(" ")

def mark_as_read(service, message_id):
    try:
        modify_request = {'removeLabelIds': ['UNREAD']}
        service.users().messages().modify(userId='me', id=message_id, body=modify_request).execute()
        print(f"Marked email with ID '{message_id}' as read.")
    except Exception as e:
        print(f"Error occurred while marking email as read: {sender}")
        
def save_as_draft(service, message_id, reply_html, subject_prefix="Re"):
    message = service.users().messages().get(userId='me', id=message_id, format='full').execute()
    headers = message['payload']['headers']

    original_sender = None
    for header in headers:
        if header['name'] == 'From':
            original_sender = header['value']

    # Parse sender's name and email address
    sender_name, sender_email = email.utils.parseaddr(original_sender)

    if not sender_email:
        print("Error: Unable to find sender's email address.")
        return

    try:
        # Construct the reply subject
        subject = [header['value'] for header in headers if header['name'] == 'Subject'][0]
        reply_subject = f"{subject_prefix}: {subject}"

        # Extract the message history
        message_history = get_message_history(service, message_id)

        # Replace newline characters with <br> tags in the message history
        message_history_html = message_history.replace('\n', '<br>')

        # Construct the HTML content with proper paragraph breaks
        reply_html_content = f"{reply_html}<br><br><br>{message_history_html}"

        # Create a MIMEText message with HTML content
        reply_message = MIMEText(reply_html_content, 'html')
        reply_message['From'] = USER_EMAIL
        reply_message['To'] = sender_email  # Use the original sender's email address
        reply_message['Subject'] = reply_subject
        reply_message['In-Reply-To'] = message['id']
        thread_id = message['threadId']

        raw_message = base64.urlsafe_b64encode(reply_message.as_bytes()).decode()

        draft = {
            'message': {
                'raw': raw_message,
                'threadId': thread_id
            }
        }

        draft = service.users().drafts().create(userId='me', body=draft).execute()

        draft_id = draft.get('id', None)
        print(f"Saved reply as draft with draft ID: {draft_id}")
        print(" ")
    except Exception as e:
        print(f"Error occurred while saving draft: {e}")
        
def main():
    creds = get_credentials()
    service = build('gmail', 'v1', credentials=creds)

    unread_emails = get_unread_emails(service)

    if not unread_emails:
        return

    for email in unread_emails:
        message_id = email['id']
        result_response = "At the moment, we have life, health, and automobile insurance..."
        list_of_sources = ["https://www.allianz.com/en/investor_relations/shareholders/faq.html"]
        result_database = {"nome":"Leonardo", "email": "leonardorpbm2@gmail.com", "insurer":"Zurich"} 
        reply_text = generateEmailLayout(result_response, list_of_sources, result_database)

        save_as_draft(service, message_id, reply_text, subject_prefix="Re")
        mark_as_read(service, message_id)  # Mark the email as read

if __name__ == "__main__":
    main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=527325279049-hffgbnq6fovohr476tk7bfg14sak0f7q.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A50117%2F&scope=https%3A%2F%2Fmail.google.com%2F&state=LhYKZ3lJfmYQNWmUDBUW9rfhQ26qEJ&access_type=offline
# {'nome': 'Leonardo', 'email': 'leonardorpbm2@gmail.com', 'insurer': 'Zurich'}
# Changed to Zurich
# Olá eu sou o Léo
#
# Saved reply as draft with draft ID: r2390621730269675787
#
# Marked email with ID '18c1fd2cb45211d0' as read.
